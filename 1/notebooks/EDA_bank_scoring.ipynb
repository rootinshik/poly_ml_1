# %%
import pandas as pd

# %%
df = pd.read_csv(
    "../data/bank_scoring/bank_scoring_train.csv", 
    delimiter="\t"
)
df
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                     0                              0.975614   39
# 1                     0                              0.006634   75
# 2                     0                              0.227432   48
# 3                     0                              0.290217   59
# 4                     0                              0.000000   80
# ...                 ...                                   ...  ...
# 96211                 0                              0.006418   55
# 96212                 0                              0.482536   37
# 96213                 0                              0.144630   56
# 96214                 0                              0.077271   77
# 96215                 0                              0.010758   80
#
#        NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                         1   0.678552         1850.0
# ...

# %%
df.dtypes
# Out:
# SeriousDlqin2yrs                          int64
# RevolvingUtilizationOfUnsecuredLines    float64
# age                                       int64
# NumberOfTime30-59DaysPastDueNotWorse      int64
# DebtRatio                               float64
# MonthlyIncome                           float64
# NumberOfOpenCreditLinesAndLoans           int64
# NumberOfTimes90DaysLate                   int64
# NumberRealEstateLoansOrLines              int64
# NumberOfTime60-89DaysPastDueNotWorse      int64
# NumberOfDependents                      float64
# dtype: object

# %%
df.describe().T
# Out:
#                                         count         mean           std  min  \
# SeriousDlqin2yrs                      96216.0     0.068845      0.253192  0.0
# RevolvingUtilizationOfUnsecuredLines  96216.0     7.029389    281.652554  0.0
# age                                   96216.0    51.293849     14.455102  0.0
# NumberOfTime30-59DaysPastDueNotWorse  96216.0     0.395766      3.660317  0.0
# DebtRatio                             96216.0    26.749151    473.157254  0.0
# MonthlyIncome                         96216.0  6660.089154  14057.927067  0.0
# NumberOfOpenCreditLinesAndLoans       96216.0     8.727166      5.133725  0.0
# NumberOfTimes90DaysLate               96216.0     0.220660      3.624471  0.0
# NumberRealEstateLoansOrLines          96216.0     1.049347      1.121732  0.0
# NumberOfTime60-89DaysPastDueNotWorse  96216.0     0.199073      3.611041  0.0
# NumberOfDependents                    96216.0     0.849911      1.147735  0.0
#
# ...

# %%
df["SeriousDlqin2yrs"].hist();

# %%
import pandas as pd

# %%
df_3 = pd.read_csv("../data/clustering/clustering_3.csv", sep="\t", header=None)
df_3
# Out:
#          0     1
# 0     1.00  1.48
# 1     2.73  4.88
# 2     7.24  0.01
# 3     1.35  3.59
# 4     0.25  3.88
# ...    ...   ...
# 1595  5.29  3.20
# 1596  6.23  0.99
# 1597  6.50  0.07
# 1598  4.02  4.33
# 1599  7.36  3.53
#
# [1600 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalled_df_3 = StandardScaler().fit_transform(df_3)
scalled_df_3
# Out:
# array([[-1.13985668, -0.79426042],
#        [-0.47108239,  1.52403888],
#        [ 1.27236967, -1.79658394],
#        ...,
#        [ 0.98630437, -1.75567277],
#        [ 0.02759902,  1.14901987],
#        [ 1.31875864,  0.60353769]], shape=(1600, 2))

# %%
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# %%
cluster = DBSCAN(eps=0.25).fit_predict(scalled_df_3)
plt.scatter(x=scalled_df_3[:, 0], y=scalled_df_3[:, 1], c=cluster)
plt.show()

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %%
silhouette_score(scalled_df_3, cluster), davies_bouldin_score(scalled_df_3, cluster)
# Out:
# (np.float64(0.14226630888024516), np.float64(1.174116507655221))
